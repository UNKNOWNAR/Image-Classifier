# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread(r'E:\Image Classification\Models\datasets\maria_sharapova\sharapova-hits-the-practice-courts-and-met-ball-kids.jpg')
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (555, 700)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[352,  38, 233, 233]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(352), np.int32(38), np.int32(233), np.int32(233))

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('E:\Image Classification\Models\datasets\Arinjay\IMG20240704135202.jpg')
plt.imshow(original_image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\ARINJAY\AppData\Local\Temp\ipykernel_16076\4061226842.py:1: SyntaxWarning: invalid escape sequence '\I'
#   original_image = cv2.imread('E:\Image Classification\Models\datasets\Arinjay\IMG20240704135202.jpg')

# %%
cropped_image = get_cropped_image_if_2_eyes('E:\Image Classification\Models\datasets\Arinjay\IMG20240704135202.jpg')
plt.imshow(cropped_image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\ARINJAY\AppData\Local\Temp\ipykernel_16076\4011065470.py:1: SyntaxWarning: invalid escape sequence '\I'
#   cropped_image = get_cropped_image_if_2_eyes('E:\Image Classification\Models\datasets\Arinjay\IMG20240704135202.jpg')

# %%
original_image = cv2.imread('E:\Image Classification\Models\datasets\Arinjay\IMG-20240708-WA0100.jpg')
plt.imshow(original_image)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\ARINJAY\AppData\Local\Temp\ipykernel_16076\667552822.py:1: SyntaxWarning: invalid escape sequence '\I'
#   original_image = cv2.imread('E:\Image Classification\Models\datasets\Arinjay\IMG-20240708-WA0100.jpg')

# %%
cropped_image = get_cropped_image_if_2_eyes('E:\Image Classification\Models\datasets\Arinjay\IMG-20240708-WA0100.jpg')
cropped_image
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\ARINJAY\AppData\Local\Temp\ipykernel_16076\4214054082.py:1: SyntaxWarning: invalid escape sequence '\I'
#   cropped_image = get_cropped_image_if_2_eyes('E:\Image Classification\Models\datasets\Arinjay\IMG-20240708-WA0100.jpg')

# %%
path_to_data = "./Models/datasets/"
path_to_cr_data = "./Models/datasets/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['./Models/datasets/Arinjay',
#  './Models/datasets/lionel_messi',
#  './Models/datasets/maria_sharapova',
#  './Models/datasets/roger_federer',
#  './Models/datasets/serena_williams',
#  './Models/datasets/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    name = img_dir.split('/')[-1]
    print(name)
    file_names_dict[name] = []
    
for entry in os.scandir(img_dir):
    roi_color = get_cropped_image_if_2_eyes(entry.path)
    if roi_color is not None:
        cropped_folder = path_to_cr_data + name
        if not os.path.exists(cropped_folder):
            os.makedirs(cropped_folder)
            cropped_image_dirs.append(cropped_folder)
            print("Generating cropped images in folder: ",cropped_folder)
            
        cropped_file_name = name + str(count) + ".png"
        cropped_file_path = cropped_folder + "/" + cropped_file_name 
        
        cv2.imwrite(cropped_file_path, roi_color)
        file_names_dict[name].append(cropped_file_path)
        count += 1
# Out:
# Arinjay
# lionel_messi
# maria_sharapova
# roger_federer
# serena_williams
# virat_kohli
